# %% [markdown]
# # YOLO v8 Custom Object Detection BY Personal Protective Equipment (PPE) for Construction

# %%
from google.colab import drive
drive.mount("drive")

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # Create Directories

# %%
import os
if not os.path.isdir("equ"):
  os.makedirs("equ")

# %%
# %cd /content/drive/MyDrive/equ/yoloNas
# Out:
# /content/drive/MyDrive/equ/yoloNas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # YOLO v8  installation

# %%
! pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.5/565.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.1/203.1 kB 26.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Installing Pytorch

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Training The Custom Dataset to detecting Hat and Jacket

# %%
# !yolo task=detect mode=train epochs=100 data=data_custom.yaml model =yolov8m.pt imgsz=640
# Out:
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Detecting From videos

# %%
# !yolo task=detect mode=predict model =yolov8m_custom.pt show=True conf=0.5 source =1.mp4
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.93 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 6 hats, 3 jackets, 63.3ms
# video 1/1 (2/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 6 hats, 3 jackets, 25.1ms
# video 1/1 (3/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 4 hats, 2 jackets, 25.1ms
# video 1/1 (4/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 4 hats, 2 jackets, 25.1ms
# video 1/1 (5/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 4 hats, 2 jackets, 25.1ms
# video 1/1 (6/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 3 hats, 3 jackets, 25.2ms
# video 1/1 (7/1506) /content/drive/MyDrive/equ/yoloNas/1.mp4: 640x384 4 hats, 3 jackets, 25.1ms
# ...

# %% [markdown]
# # Thank you

# %%
import matplotlib.pyplot

# %%
import IPython.display as display
from PIL import Image
image_path = '/content/drive/MyDrive/equ/yoloNas/runs/detect/predict/1.jpg'
display.display(Image.open(image_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1023x683 at 0x7F1BE4E03BE0>
